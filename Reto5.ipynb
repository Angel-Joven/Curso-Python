# %% [markdown]
# # Reto 5:
#
# ---

# %% [markdown]
# ## Ejercicio 1: Funciones

# %% [markdown]
# De nuestro código que evaluaba cual era una el número mayor, convertirla a función.
#
# Entrada: num1, num2
#
# Salida:
#
# 1. El num1 es mayor que num2
# 2. El num2 es mayor que num2
# 3. Ambos son iguales

# %%
def numeroMayorMenor(num1, num2):
    if num1 > num2:
        return f"El numero {num1} es mayor que el numero {num2}"
    elif num2 > num1:
        return f"El numero {num2} es mayor que el numero {num1}"
    else:
        return f"El numero {num1} es igual al numero {num2}"

numeroMayorMenor(10, 2)
# Out:
# 'El numero 10 es mayor que el numero 2'

# %% [markdown]
# ## Ejercicio 2:

# %% [markdown]
# Crear una función que reciba como parameto un texto y que devuelva en el `return` una lista que contenga cada palabra del texto.
#
# |Entrada | Salida |
# | - | - |
# | "El señor de los anillos" | ["El", "señor", "de", "los", "anillos"] |
#
#
#
# Utiliar el metodo .split() al texto
#
# **Ejemplo**
#
# "Buenos días".split()

# %%
def textoAlista(texto):
    resultado = []
    resultado = texto.split()
    return resultado

textoAlista("El señor de los anillos")
# Out:
# ['El', 'señor', 'de', 'los', 'anillos']

# %%
pass # No hace nada

# %% [markdown]
# ## Ejercicio 3:

# %% [markdown]
# Un piloto de carreras ha registrado su velocidad cada segundo en la siguiente lista:
#
# velocidad = [0, 60, 80, 117, 140, 155, 170, 189, 205, 223, 234, 239, 234, 227, 215, 180, 155, 160, 189, 206, 235]
#
# Hacer una función que imprima en que segundo el piloto rebaso los 210 km/h
#
#
# **Ejemplo de impresión**
#
# En el segundo `9` el piloto llego a los `223` km/h

# %%
velocidad = [0, 60, 80, 117, 140, 155, 170, 189, 205, 223, 234, 239, 234, 227, 215, 180, 155, 160, 189, 206, 235]

def pilotoMayor210(velocidades):
    segundos = 0
    for velocidad in velocidades:
        segundos = segundos + 1
        if velocidad > 210:
            print(f"En el segundo {segundos} el piloto llego a los {velocidad} km/h")
        else:
            print("El piloto no rebaso los 210 km/h")

pilotoMayor210(velocidad)
# Out:
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# En el segundo 10 el piloto llego a los 223 km/h
# En el segundo 11 el piloto llego a los 234 km/h
# En el segundo 12 el piloto llego a los 239 km/h
# En el segundo 13 el piloto llego a los 234 km/h
# En el segundo 14 el piloto llego a los 227 km/h
# En el segundo 15 el piloto llego a los 215 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# El piloto no rebaso los 210 km/h
# En el segundo 21 el piloto llego a los 235 km/h

# %% [markdown]
# ## Extra points

# %% [markdown]
# Hacer una función que nos imprima cuantos números pares e impares tiene una lista.
#
# Para evaluar un par o impar puedes utilizar el
#
# ```Python
# if numero%2 = 0:
#     print("numero es par")
# else:
#     print("numero es impar")
# ```
#
# |Entrada | Salida |
# | - | - |
# | [2,3,6,8,9] | Tiene `3` pares y `2` inpares |

# %%
def paresImpares(una_lista):
    contador_par = 0
    contador_impar = 0

    for numero in una_lista:
        if numero%2 == 0:
            contador_par += 1
        else:
            contador_impar += 1
    return f'Tiene {contador_par} pares y {contador_impar} impares'

numeros = [2,3,6,8,9]

paresImpares(numeros)
# Out:
# 'Tiene 3 pares y 2 impares'
